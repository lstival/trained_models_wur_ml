# %% [markdown]
# # TorchVision Object Detection Finetuning Tutorial

# %% [markdown]
# #### Download the data
# wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip -P data
# cd data && unzip PennFudanPed.zip
#
# #### If in windows machine
# Invoke-WebRequest -Uri "https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip" -OutFile "file.zip"
#
# powershell -command "Expand-Archive -Path 'file.zip' -DestinationPath '.'"

# %% [markdown]
# For this tutorial, we will be finetuning a pre-trained [Mask
# R-CNN](https://arxiv.org/abs/1703.06870) model on the [Penn-Fudan
# Database for Pedestrian Detection and
# Segmentation](https://www.cis.upenn.edu/~jshi/ped_html/). It contains
# 170 images with 345 instances of pedestrians, and we will use it to
# illustrate how to use the new features in torchvision in order to train
# an object detection and instance segmentation model on a custom dataset.
#
# Defining the Dataset
# ====================
#
# The reference scripts for training object detection, instance
# segmentation and person keypoint detection allows for easily supporting
# adding new custom datasets. The dataset should inherit from the standard
# `torch.utils.data.Dataset`{.interpreted-text role="class"} class, and
# implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__`
# should return a tuple:
#
# -   image: `torchvision.tv_tensors.Image`{.interpreted-text
#     role="class"} of shape `[3, H, W]`, a pure tensor, or a PIL Image of
#     size `(H, W)`
# -   target: a dict containing the following fields
#     -   `boxes`,
#         `torchvision.tv_tensors.BoundingBoxes`{.interpreted-text
#         role="class"} of shape `[N, 4]`: the coordinates of the `N`
#         bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to
#         `W` and `0` to `H`
#     -   `labels`, integer `torch.Tensor`{.interpreted-text role="class"}
#         of shape `[N]`: the label for each bounding box. `0` represents
#         always the background class.
#     -   `image_id`, int: an image identifier. It should be unique
#         between all the images in the dataset, and is used during
#         evaluation
#     -   `area`, float `torch.Tensor`{.interpreted-text role="class"} of
#         shape `[N]`: the area of the bounding box. This is used during
#         evaluation with the COCO metric, to separate the metric scores
#         between small, medium and large boxes.
#     -   `iscrowd`, uint8 `torch.Tensor`{.interpreted-text role="class"}
#         of shape `[N]`: instances with `iscrowd=True` will be ignored
#         during evaluation.
#     -   (optionally) `masks`,
#         `torchvision.tv_tensors.Mask`{.interpreted-text role="class"} of
#         shape `[N, H, W]`: the segmentation masks for each one of the
#         objects
#
# If your dataset is compliant with above requirements then it will work
# for both training and evaluation codes from the reference script.
# Evaluation code will use scripts from `pycocotools` which can be
# installed with `pip install pycocotools`.
#
# One note on the `labels`. The model considers class `0` as background.
# If your dataset does not contain the background class, you should not
# have `0` in your `labels`. For example, assuming you have just two
# classes, *cat* and *dog*, you can define `1` (not `0`) to represent
# *cats* and `2` to represent *dogs*. So, for instance, if one of the
# images has both classes, your `labels` tensor should look like `[1, 2]`.
#
# Additionally, if you want to use aspect ratio grouping during training
# (so that each batch only contains images with similar aspect ratios),
# then it is recommended to also implement a `get_height_and_width`
# method, which returns the height and the width of the image. If this
# method is not provided, we query all elements of the dataset via
# `__getitem__` , which loads the image in memory and is slower than if a
# custom method is provided.
#
# Writing a custom dataset for PennFudan
# --------------------------------------
#
# Let's write a dataset for the PennFudan dataset. First, let\'s download
# the dataset and extract the [zip
# file](https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip):
#
# ``` {.python}
# wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip -P data
# cd data && unzip PennFudanPed.zip
# ```
#
# We have the following folder structure:
#
#     PennFudanPed/
#       PedMasks/
#         FudanPed00001_mask.png
#         FudanPed00002_mask.png
#         FudanPed00003_mask.png
#         FudanPed00004_mask.png
#         ...
#       PNGImages/
#         FudanPed00001.png
#         FudanPed00002.png
#         FudanPed00003.png
#         FudanPed00004.png
#
# Here is one example of a pair of images and segmentation masks

# %%
# !wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip -P data
# !cd data && unzip PennFudanPed.zip

# %%
import matplotlib.pyplot as plt
from torchvision.io import read_image
import matplotlib.pyplot as plt
from torchvision.utils import draw_bounding_boxes, draw_segmentation_masks


image = read_image("data/PennFudanPed/PNGImages/FudanPed00046.png")
mask = read_image("data/PennFudanPed/PedMasks/FudanPed00046_mask.png")

plt.figure(figsize=(16, 8))
plt.subplot(121)
plt.title("Image")
plt.imshow(image.permute(1, 2, 0))
plt.subplot(122)
plt.title("Mask")
plt.imshow(mask.permute(1, 2, 0))

# %% [markdown]
# ### Dataset Class and DataLoader
#
# So each image has a corresponding segmentation mask, where each color
# correspond to a different instance. Let's write a
# `torch.utils.data.Dataset`{.interpreted-text role="class"} class for
# this dataset. In the code below, we are wrapping images, bounding boxes
# and masks into `torchvision.tv_tensors.TVTensor`{.interpreted-text
# role="class"} classes so that we will be able to apply torchvision
# built-in transformations ([new Transforms
# API](https://pytorch.org/vision/stable/transforms.html)) for the given
# object detection and segmentation task. Namely, image tensors will be
# wrapped by `torchvision.tv_tensors.Image`{.interpreted-text
# role="class"}, bounding boxes into
# `torchvision.tv_tensors.BoundingBoxes`{.interpreted-text role="class"}
# and masks into `torchvision.tv_tensors.Mask`{.interpreted-text
# role="class"}. As `torchvision.tv_tensors.TVTensor`{.interpreted-text
# role="class"} are `torch.Tensor`{.interpreted-text role="class"}
# subclasses, wrapped objects are also tensors and inherit the plain
# `torch.Tensor`{.interpreted-text role="class"} API. For more information
# about torchvision `tv_tensors` see [this
# documentation](https://pytorch.org/vision/main/auto_examples/transforms/plot_transforms_getting_started.html#what-are-tvtensors).

# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F


class PennFudanDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))

    def __getitem__(self, idx):
        # load images and masks
        img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])
        img = read_image(img_path)
        mask = read_image(mask_path)
        # instances are encoded as different colors
        obj_ids = torch.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]
        num_objs = len(obj_ids)

        # split the color-encoded mask into a set
        # of binary masks
        masks = (mask == obj_ids[:, None, None]).to(dtype=torch.uint8)

        # get bounding box coordinates for each mask
        boxes = masks_to_boxes(masks)

        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)

        image_id = idx
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Wrap sample and targets into torchvision tv_tensors:
        img = tv_tensors.Image(img)

        target = {}
        target["boxes"] = tv_tensors.BoundingBoxes(boxes, format="XYXY", canvas_size=F.get_size(img))
        target["masks"] = tv_tensors.Mask(masks)
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# That's all for the dataset. Now let's define a model that can perform
# predictions on this dataset.
#
# Defining your model
# ===================
#
# In this tutorial, we will be using [Mask
# R-CNN](https://arxiv.org/abs/1703.06870), which is based on top of
# [Faster R-CNN](https://arxiv.org/abs/1506.01497). Faster R-CNN is a
# model that predicts both bounding boxes and class scores for potential
# objects in the image.
#
# ![image](https://pytorch.org/tutorials/_static/img/tv_tutorial/tv_image03.png)
#
# Mask R-CNN adds an extra branch into Faster R-CNN, which also predicts
# segmentation masks for each instance.
#
# ![image](https://pytorch.org/tutorials/_static/img/tv_tutorial/tv_image04.png)
#
# There are two common situations where one might want to modify one of
# the available models in TorchVision Model Zoo. The first is when we want
# to start from a pre-trained model, and just finetune the last layer. The
# other is when we want to replace the backbone of the model with a
# different one (for faster predictions, for example).
#
# Let's go see how we would do one or another in the following sections.
#
# 1 - Finetuning from a pretrained model
# --------------------------------------
#
# Let's suppose that you want to start from a model pre-trained on COCO
# and want to finetune it for your particular classes. Here is a possible
# way of doing it:

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# load a model pre-trained on COCO
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")

# replace the classifier with a new one, that has
# num_classes which is user-defined
num_classes = 2  # 1 class (person) + background
# get number of input features for the classifier
in_features = model.roi_heads.box_predictor.cls_score.in_features
# replace the pre-trained head with a new one
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# %% [markdown]
# 2 - Modifying the model to add a different backbone
# ===================================================

# %%
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

# load a pre-trained model for classification and return
# only the features
backbone = torchvision.models.mobilenet_v2(weights="DEFAULT").features
# ``FasterRCNN`` needs to know the number of
# output channels in a backbone. For mobilenet_v2, it's 1280
# so we need to add it here
backbone.out_channels = 1280

# let's make the RPN generate 5 x 3 anchors per spatial
# location, with 5 different sizes and 3 different aspect
# ratios. We have a Tuple[Tuple[int]] because each feature
# map could potentially have different sizes and
# aspect ratios
anchor_generator = AnchorGenerator(
    sizes=((32, 64, 128, 256, 512),),
    aspect_ratios=((0.5, 1.0, 2.0),)
)

# let's define what are the feature maps that we will
# use to perform the region of interest cropping, as well as
# the size of the crop after rescaling.
# if your backbone returns a Tensor, featmap_names is expected to
# be [0]. More generally, the backbone should return an
# ``OrderedDict[Tensor]``, and in ``featmap_names`` you can choose which
# feature maps to use.
roi_pooler = torchvision.ops.MultiScaleRoIAlign(
    featmap_names=['0'],
    output_size=7,
    sampling_ratio=2
)

# put the pieces together inside a Faster-RCNN model
model = FasterRCNN(
    backbone,
    num_classes=2,
    rpn_anchor_generator=anchor_generator,
    box_roi_pool=roi_pooler
)

# %% [markdown]
# Object detection and instance segmentation model for PennFudan Dataset
# ======================================================================
#
# In our case, we want to finetune from a pre-trained model, given that
# our dataset is very small, so we will be following approach number 1.
#
# Here we want to also compute the instance segmentation masks, so we will
# be using Mask R-CNN:

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor


def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(weights="DEFAULT")

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(
        in_features_mask,
        hidden_layer,
        num_classes
    )

    return model

# %% [markdown]
# That's it, this will make `model` be ready to be trained and evaluated
# on your custom dataset.
#
# Putting everything together
# ===========================
#
# In `references/detection/`, we have a number of helper functions to
# simplify training and evaluating detection models. Here, we will use
# `references/detection/engine.py` and `references/detection/utils.py`.
# Just download everything under `references/detection` to your folder and
# use them here. On Linux if you have `wget`, you can download them using
# below commands:

# %%
from pathlib import Path
from urllib.request import urlretrieve

urls = [
    "https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py",
    "https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py",
    "https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py",
    "https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py",
    "https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py",
]

target_dir = Path("")
target_dir.mkdir(parents=True, exist_ok=True)

for url in urls:
    destination = target_dir / Path(url).name
    if destination.exists():
        print(f"Skipping {destination.name}, already exists.")
        continue
    print(f"Downloading {destination.name}...")
    urlretrieve(url, destination)

print("Download complete.")
# Out:
# Skipping engine.py, already exists.
# Skipping utils.py, already exists.
# Skipping coco_utils.py, already exists.
# Skipping coco_eval.py, already exists.
# Skipping transforms.py, already exists.
# Download complete.

# %% [markdown]
# Since v0.15.0 torchvision provides [new Transforms
# API](https://pytorch.org/vision/stable/transforms.html) to easily write
# data augmentation pipelines for Object Detection and Segmentation tasks.
#
# Let's write some helper functions for data augmentation /
# transformation:

# %%
from torchvision.transforms import v2 as T


def get_transform(train):
    transforms = []
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToDtype(torch.float, scale=True))
    transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

# %% [markdown]
# Testing `forward()` method (Optional)
# =====================================
#
# Before iterating over the dataset, it\'s good to see what the model
# expects during training and inference time on sample data.

# %%
import utils

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")
dataset = PennFudanDataset('data/PennFudanPed', get_transform(train=True))
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    collate_fn=utils.collate_fn
)

# For Training
images, targets = next(iter(data_loader))
images = list(image for image in images)
targets = [{k: v for k, v in t.items()} for t in targets]
output = model(images, targets)  # Returns losses and detections
print(output)

# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x)  # Returns predictions
print(predictions[0])
# Out:
# {'loss_classifier': tensor(0.2640, grad_fn=<NllLossBackward0>), 'loss_box_reg': tensor(0.0336, grad_fn=<DivBackward0>), 'loss_objectness': tensor(0.0348, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>), 'loss_rpn_box_reg': tensor(0.0018, grad_fn=<DivBackward0>)}
# {'boxes': tensor([], size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], dtype=torch.int64), 'scores': tensor([], grad_fn=<IndexBackward0>)}
# {'boxes': tensor([], size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], dtype=torch.int64), 'scores': tensor([], grad_fn=<IndexBackward0>)}

# %% [markdown]
# We want to be able to train our model on an
# [accelerator](https://pytorch.org/docs/stable/torch.html#accelerators)
# such as CUDA, MPS, MTIA, or XPU. Let's now write the main function which
# performs the training and the validation:

# %%
from engine import train_one_epoch, evaluate

# train on the accelerator or on the CPU, if an accelerator is not available
device = torch.accelerator.current_accelerator() if torch.accelerator.is_available() else torch.device('cpu')

# our dataset has two classes only - background and person
num_classes = 2
# use our dataset and defined transformations
dataset = PennFudanDataset('data/PennFudanPed', get_transform(train=True))
dataset_test = PennFudanDataset('data/PennFudanPed', get_transform(train=False))

# split the dataset in train and test set
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:-50])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    collate_fn=utils.collate_fn
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    collate_fn=utils.collate_fn
)

# get the model using our helper function
model = get_model_instance_segmentation(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# let's train it just for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

print("That's it!")
# Out:
# c:\WUR\ML_Ricardo_Tutorials\Computer Vision\engine.py:30: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# Epoch: [0]  [ 0/60]  eta: 0:01:27  lr: 0.000090  loss: 2.8331 (2.8331)  loss_classifier: 0.5992 (0.5992)  loss_box_reg: 0.1528 (0.1528)  loss_mask: 2.0769 (2.0769)  loss_objectness: 0.0039 (0.0039)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 1.4662  data: 0.0164  max mem: 1792
# Epoch: [0]  [10/60]  eta: 0:00:14  lr: 0.000936  loss: 1.6673 (1.8107)  loss_classifier: 0.3955 (0.3973)  loss_box_reg: 0.2445 (0.2883)  loss_mask: 0.8724 (1.0965)  loss_objectness: 0.0185 (0.0248)  loss_rpn_box_reg: 0.0032 (0.0038)  time: 0.2924  data: 0.0123  max mem: 2599
# Epoch: [0]  [10/60]  eta: 0:00:14  lr: 0.000936  loss: 1.6673 (1.8107)  loss_classifier: 0.3955 (0.3973)  loss_box_reg: 0.2445 (0.2883)  loss_mask: 0.8724 (1.0965)  loss_objectness: 0.0185 (0.0248)  loss_rpn_box_reg: 0.0032 (0.0038)  time: 0.2924  data: 0.0123  max mem: 2599
# Epoch: [0]  [20/60]  eta: 0:00:09  lr: 0.001783  loss: 0.9163 (1.2690)  loss_classifier: 0.2198 (0.2809)  loss_box_reg: 0.2182 (0.2580)  loss_mask: 0.3344 (0.7050)  loss_objectness: 0.0176 (0.0202)  loss_rpn_box_reg: 0.0044 (0.0049)  time: 0.1742  data: 0.0137  max mem: 2599
# Epoch: [0]  [20/60]  eta: 0:00:09  lr: 0.001783  loss: 0.9163 (1.2690)  loss_classifier: 0.2198 (0.2809)  loss_box_reg: 0.2182 (0.2580)  loss_mask: 0.3344 (0.7050)  loss_objectness: 0.0176 (0.0202)  loss_rpn_box_reg: 0.0044 (0.0049)  time: 0.1742  data: 0.0137  max mem: 2599
# Epoch: [0]  [30/60]  eta: 0:00:06  lr: 0.002629  loss: 0.5790 (1.0427)  loss_classifier: 0.0939 (0.2198)  loss_box_reg: 0.2173 (0.2568)  loss_mask: 0.2255 (0.5425)  loss_objectness: 0.0122 (0.0167)  loss_rpn_box_reg: 0.0058 (0.0069)  time: 0.1783  data: 0.0160  max mem: 2599
# Epoch: [0]  [30/60]  eta: 0:00:06  lr: 0.002629  loss: 0.5790 (1.0427)  loss_classifier: 0.0939 (0.2198)  loss_box_reg: 0.2173 (0.2568)  loss_mask: 0.2255 (0.5425)  loss_objectness: 0.0122 (0.0167)  loss_rpn_box_reg: 0.0058 (0.0069)  time: 0.1783  data: 0.0160  max mem: 2599
# Epoch: [0]  [40/60]  eta: 0:00:04  lr: 0.003476  loss: 0.4639 (0.8892)  loss_classifier: 0.0572 (0.1799)  loss_box_reg: 0.2112 (0.2411)  loss_mask: 0.1672 (0.4480)  loss_objectness: 0.0036 (0.0136)  loss_rpn_box_reg: 0.0055 (0.0065)  time: 0.1843  data: 0.0151  max mem: 2743
# Epoch: [0]  [40/60]  eta: 0:00:04  lr: 0.003476  loss: 0.4639 (0.8892)  loss_classifier: 0.0572 (0.1799)  loss_box_reg: 0.2112 (0.2411)  loss_mask: 0.1672 (0.4480)  loss_objectness: 0.0036 (0.0136)  loss_rpn_box_reg: 0.0055 (0.0065)  time: 0.1843  data: 0.0151  max mem: 2743
# Epoch: [0]  [50/60]  eta: 0:00:02  lr: 0.004323  loss: 0.3636 (0.7853)  loss_classifier: 0.0406 (0.1532)  loss_box_reg: 0.1425 (0.2193)  loss_mask: 0.1539 (0.3955)  loss_objectness: 0.0025 (0.0113)  loss_rpn_box_reg: 0.0043 (0.0060)  time: 0.1783  data: 0.0133  max mem: 2743
# Epoch: [0]  [50/60]  eta: 0:00:02  lr: 0.004323  loss: 0.3636 (0.7853)  loss_classifier: 0.0406 (0.1532)  loss_box_reg: 0.1425 (0.2193)  loss_mask: 0.1539 (0.3955)  loss_objectness: 0.0025 (0.0113)  loss_rpn_box_reg: 0.0043 (0.0060)  time: 0.1783  data: 0.0133  max mem: 2743
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.3644 (0.7250)  loss_classifier: 0.0446 (0.1386)  loss_box_reg: 0.1422 (0.2090)  loss_mask: 0.1654 (0.3612)  loss_objectness: 0.0016 (0.0101)  loss_rpn_box_reg: 0.0034 (0.0061)  time: 0.1858  data: 0.0151  max mem: 2825
# Epoch: [0] Total time: 0:00:12 (0.2025 s / it)
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.3644 (0.7250)  loss_classifier: 0.0446 (0.1386)  loss_box_reg: 0.1422 (0.2090)  loss_mask: 0.1654 (0.3612)  loss_objectness: 0.0016 (0.0101)  loss_rpn_box_reg: 0.0034 (0.0061)  time: 0.1858  data: 0.0151  max mem: 2825
# Epoch: [0] Total time: 0:00:12 (0.2025 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:02  model_time: 0.0378 (0.0378)  evaluator_time: 0.0000 (0.0000)  time: 0.0519  data: 0.0000  max mem: 2825
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:02  model_time: 0.0378 (0.0378)  evaluator_time: 0.0000 (0.0000)  time: 0.0519  data: 0.0000  max mem: 2825
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0334 (0.0421)  evaluator_time: 0.0000 (0.0030)  time: 0.0467  data: 0.0074  max mem: 2825
# Test: Total time: 0:00:02 (0.0537 s / it)
# Averaged stats: model_time: 0.0334 (0.0421)  evaluator_time: 0.0000 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.982
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.885
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.725
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.779
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.987
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.867
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.734
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.738
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0334 (0.0421)  evaluator_time: 0.0000 (0.0030)  time: 0.0467  data: 0.0074  max mem: 2825
# Test: Total time: 0:00:02 (0.0537 s / it)
# Averaged stats: model_time: 0.0334 (0.0421)  evaluator_time: 0.0000 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.714
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.982
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.885
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.725
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.779
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.987
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.867
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.460
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.734
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.738
# Epoch: [1]  [ 0/60]  eta: 0:00:11  lr: 0.005000  loss: 0.2936 (0.2936)  loss_classifier: 0.0397 (0.0397)  loss_box_reg: 0.0869 (0.0869)  loss_mask: 0.1575 (0.1575)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0089 (0.0089)  time: 0.1999  data: 0.0173  max mem: 2825
# Epoch: [1]  [ 0/60]  eta: 0:00:11  lr: 0.005000  loss: 0.2936 (0.2936)  loss_classifier: 0.0397 (0.0397)  loss_box_reg: 0.0869 (0.0869)  loss_mask: 0.1575 (0.1575)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0089 (0.0089)  time: 0.1999  data: 0.0173  max mem: 2825
# Epoch: [1]  [10/60]  eta: 0:00:09  lr: 0.005000  loss: 0.2773 (0.3047)  loss_classifier: 0.0430 (0.0422)  loss_box_reg: 0.0869 (0.0965)  loss_mask: 0.1408 (0.1564)  loss_objectness: 0.0017 (0.0026)  loss_rpn_box_reg: 0.0083 (0.0070)  time: 0.1864  data: 0.0143  max mem: 2825
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0365 (0.0418)  evaluator_time: 0.0000 (0.0031)  time: 0.0475  data: 0.0042  max mem: 2825
# Test: Total time: 0:00:02 (0.0500 s / it)
# Averaged stats: model_time: 0.0365 (0.0418)  evaluator_time: 0.0000 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.903
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.859
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.539
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.756
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0365 (0.0418)  evaluator_time: 0.0000 (0.0031)  time: 0.0475  data: 0.0042  max mem: 2825
# Test: Total time: 0:00:02 (0.0500 s / it)
# Averaged stats: model_time: 0.0365 (0.0418)  evaluator_time: 0.0000 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.903
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.859
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.896
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.539
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.756
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.794
# Epoch: [4]  [ 0/60]  eta: 0:00:14  lr: 0.000500  loss: 0.1665 (0.1665)  loss_classifier: 0.0248 (0.0248)  loss_box_reg: 0.0396 (0.0396)  loss_mask: 0.0985 (0.0985)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 0.2500  data: 0.0165  max mem: 2825
# Epoch: [4]  [ 0/60]  eta: 0:00:14  lr: 0.000500  loss: 0.1665 (0.1665)  loss_classifier: 0.0248 (0.0248)  loss_box_reg: 0.0396 (0.0396)  loss_mask: 0.0985 (0.0985)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 0.2500  data: 0.0165  max mem: 2825
# Epoch: [4]  [10/60]  eta: 0:00:11  lr: 0.000500  loss: 0.1783 (0.2007)  loss_classifier: 0.0248 (0.0283)  loss_box_reg: 0.0396 (0.0450)  loss_mask: 0.1178 (0.1227)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0025 (0.0029)  time: 0.2229  data: 0.0144  max mem: 2825
# Epoch: [4]  [10/60]  eta: 0:00:11  lr: 0.000500  loss: 0.1783 (0.2007)  loss_classifier: 0.0248 (0.0283)  loss_box_reg: 0.0396 (0.0450)  loss_mask: 0.1178 (0.1227)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0025 (0.0029)  time: 0.2229  data: 0.0144  max mem: 2825
# Epoch: [4]  [20/60]  eta: 0:00:09  lr: 0.000500  loss: 0.1752 (0.1889)  loss_classifier: 0.0253 (0.0266)  loss_box_reg: 0.0318 (0.0402)  loss_mask: 0.1175 (0.1181)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0025 (0.0029)  time: 0.2264  data: 0.0154  max mem: 2825
# Epoch: [4]  [20/60]  eta: 0:00:09  lr: 0.000500  loss: 0.1752 (0.1889)  loss_classifier: 0.0253 (0.0266)  loss_box_reg: 0.0318 (0.0402)  loss_mask: 0.1175 (0.1181)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0025 (0.0029)  time: 0.2264  data: 0.0154  max mem: 2825
# Epoch: [4]  [30/60]  eta: 0:00:06  lr: 0.000500  loss: 0.1714 (0.1936)  loss_classifier: 0.0253 (0.0267)  loss_box_reg: 0.0322 (0.0425)  loss_mask: 0.1173 (0.1203)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0026 (0.0032)  time: 0.2266  data: 0.0153  max mem: 2825
# Epoch: [4]  [30/60]  eta: 0:00:06  lr: 0.000500  loss: 0.1714 (0.1936)  loss_classifier: 0.0253 (0.0267)  loss_box_reg: 0.0322 (0.0425)  loss_mask: 0.1173 (0.1203)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0026 (0.0032)  time: 0.2266  data: 0.0153  max mem: 2825
# Epoch: [4]  [40/60]  eta: 0:00:04  lr: 0.000500  loss: 0.1729 (0.1884)  loss_classifier: 0.0234 (0.0265)  loss_box_reg: 0.0329 (0.0398)  loss_mask: 0.1117 (0.1182)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0019 (0.0029)  time: 0.2131  data: 0.0150  max mem: 2825
# Epoch: [4]  [40/60]  eta: 0:00:04  lr: 0.000500  loss: 0.1729 (0.1884)  loss_classifier: 0.0234 (0.0265)  loss_box_reg: 0.0329 (0.0398)  loss_mask: 0.1117 (0.1182)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0019 (0.0029)  time: 0.2131  data: 0.0150  max mem: 2825
# Epoch: [4]  [50/60]  eta: 0:00:02  lr: 0.000500  loss: 0.1696 (0.1888)  loss_classifier: 0.0252 (0.0270)  loss_box_reg: 0.0329 (0.0408)  loss_mask: 0.1072 (0.1172)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0019 (0.0030)  time: 0.2167  data: 0.0163  max mem: 2825
# Epoch: [4]  [50/60]  eta: 0:00:02  lr: 0.000500  loss: 0.1696 (0.1888)  loss_classifier: 0.0252 (0.0270)  loss_box_reg: 0.0329 (0.0408)  loss_mask: 0.1072 (0.1172)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0019 (0.0030)  time: 0.2167  data: 0.0163  max mem: 2825
# Epoch: [4]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1543 (0.1826)  loss_classifier: 0.0178 (0.0256)  loss_box_reg: 0.0253 (0.0381)  loss_mask: 0.1065 (0.1151)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0016 (0.0028)  time: 0.2106  data: 0.0153  max mem: 2825
# Epoch: [4] Total time: 0:00:13 (0.2178 s / it)
# Epoch: [4]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.1543 (0.1826)  loss_classifier: 0.0178 (0.0256)  loss_box_reg: 0.0253 (0.0381)  loss_mask: 0.1065 (0.1151)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0016 (0.0028)  time: 0.2106  data: 0.0153  max mem: 2825
# Epoch: [4] Total time: 0:00:13 (0.2178 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:02  model_time: 0.0495 (0.0495)  evaluator_time: 0.0000 (0.0000)  time: 0.0495  data: 0.0000  max mem: 2825
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:02  model_time: 0.0495 (0.0495)  evaluator_time: 0.0000 (0.0000)  time: 0.0495  data: 0.0000  max mem: 2825
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0338 (0.0392)  evaluator_time: 0.0000 (0.0033)  time: 0.0475  data: 0.0048  max mem: 2825
# Test: Total time: 0:00:02 (0.0503 s / it)
# Averaged stats: model_time: 0.0338 (0.0392)  evaluator_time: 0.0000 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.792
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.862
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.893
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.452
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.785
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.795
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0338 (0.0392)  evaluator_time: 0.0000 (0.0033)  time: 0.0475  data: 0.0048  max mem: 2825
# Test: Total time: 0:00:02 (0.0503 s / it)
# Averaged stats: model_time: 0.0338 (0.0392)  evaluator_time: 0.0000 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.00s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.792
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.862
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.893
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.452
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.785
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.795
# Epoch: [5]  [ 0/60]  eta: 0:00:12  lr: 0.000500  loss: 0.1857 (0.1857)  loss_classifier: 0.0252 (0.0252)  loss_box_reg: 0.0356 (0.0356)  loss_mask: 0.1231 (0.1231)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 0.2143  data: 0.0141  max mem: 2825
# Epoch: [5]  [ 0/60]  eta: 0:00:12  lr: 0.000500  loss: 0.1857 (0.1857)  loss_classifier: 0.0252 (0.0252)  loss_box_reg: 0.0356 (0.0356)  loss_mask: 0.1231 (0.1231)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 0.2143  data: 0.0141  max mem: 2825
# Epoch: [5]  [10/60]  eta: 0:00:10  lr: 0.000500  loss: 0.1635 (0.1715)  loss_classifier: 0.0191 (0.0207)  loss_box_reg: 0.0315 (0.0313)  loss_mask: 0.1126 (0.1161)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0016 (0.0028)  time: 0.2083  data: 0.0160  max mem: 2825
# Epoch: [5]  [10/60]  eta: 0:00:10  lr: 0.000500  loss: 0.1635 (0.1715)  loss_classifier: 0.0191 (0.0207)  loss_box_reg: 0.0315 (0.0313)  loss_mask: 0.1126 (0.1161)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0016 (0.0028)  time: 0.2083  data: 0.0160  max mem: 2825
# Epoch: [5]  [20/60]  eta: 0:00:08  lr: 0.000500  loss: 0.1635 (0.1734)  loss_classifier: 0.0210 (0.0223)  loss_box_reg: 0.0315 (0.0337)  loss_mask: 0.1045 (0.1139)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0020 (0.0029)  time: 0.2088  data: 0.0153  max mem: 2825
# Epoch: [5]  [20/60]  eta: 0:00:08  lr: 0.000500  loss: 0.1635 (0.1734)  loss_classifier: 0.0210 (0.0223)  loss_box_reg: 0.0315 (0.0337)  loss_mask: 0.1045 (0.1139)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0020 (0.0029)  time: 0.2088  data: 0.0153  max mem: 2825
# Epoch: [5]  [30/60]  eta: 0:00:06  lr: 0.000500  loss: 0.1712 (0.1787)  loss_classifier: 0.0236 (0.0240)  loss_box_reg: 0.0348 (0.0346)  loss_mask: 0.1060 (0.1164)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0020 (0.0029)  time: 0.2186  data: 0.0154  max mem: 2825
# Epoch: [5]  [30/60]  eta: 0:00:06  lr: 0.000500  loss: 0.1712 (0.1787)  loss_classifier: 0.0236 (0.0240)  loss_box_reg: 0.0348 (0.0346)  loss_mask: 0.1060 (0.1164)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0020 (0.0029)  time: 0.2186  data: 0.0154  max mem: 2825
# Epoch: [5]  [40/60]  eta: 0:00:04  lr: 0.000500  loss: 0.1763 (0.1849)  loss_classifier: 0.0259 (0.0255)  loss_box_reg: 0.0376 (0.0377)  loss_mask: 0.1062 (0.1176)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0030 (0.0032)  time: 0.2284  data: 0.0164  max mem: 2825
# Epoch: [5]  [40/60]  eta: 0:00:04  lr: 0.000500  loss: 0.1763 (0.1849)  loss_classifier: 0.0259 (0.0255)  loss_box_reg: 0.0376 (0.0377)  loss_mask: 0.1062 (0.1176)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0030 (0.0032)  time: 0.2284  data: 0.0164  max mem: 2825
# Epoch: [5]  [50/60]  eta: 0:00:02  lr: 0.000500  loss: 0.1626 (0.1805)  loss_classifier: 0.0275 (0.0251)  loss_box_reg: 0.0345 (0.0365)  loss_mask: 0.1062 (0.1151)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 0.2217  data: 0.0161  max mem: 2825
# Epoch: [5]  [50/60]  eta: 0:00:02  lr: 0.000500  loss: 0.1626 (0.1805)  loss_classifier: 0.0275 (0.0251)  loss_box_reg: 0.0345 (0.0365)  loss_mask: 0.1062 (0.1151)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 0.2217  data: 0.0161  max mem: 2825
# ...
# Epoch: [8]  [30/60]  eta: 0:00:06  lr: 0.000050  loss: 0.1856 (0.1735)  loss_classifier: 0.0258 (0.0246)  loss_box_reg: 0.0357 (0.0337)  loss_mask: 0.1106 (0.1117)  loss_objectness: 0.0004 (0.0005)  loss_rpn_box_reg: 0.0024 (0.0030)  time: 0.2182  data: 0.0162  max mem: 2825
# Epoch: [8]  [40/60]  eta: 0:00:04  lr: 0.000050  loss: 0.1849 (0.1769)  loss_classifier: 0.0262 (0.0249)  loss_box_reg: 0.0375 (0.0348)  loss_mask: 0.1130 (0.1138)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0019 (0.0028)  time: 0.2275  data: 0.0146  max mem: 2825
# Epoch: [8]  [40/60]  eta: 0:00:04  lr: 0.000050  loss: 0.1849 (0.1769)  loss_classifier: 0.0262 (0.0249)  loss_box_reg: 0.0375 (0.0348)  loss_mask: 0.1130 (0.1138)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0019 (0.0028)  time: 0.2275  data: 0.0146  max mem: 2825
# Epoch: [8]  [50/60]  eta: 0:00:02  lr: 0.000050  loss: 0.1738 (0.1761)  loss_classifier: 0.0216 (0.0240)  loss_box_reg: 0.0293 (0.0344)  loss_mask: 0.1138 (0.1143)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0019 (0.0027)  time: 0.2163  data: 0.0144  max mem: 2825
# Epoch: [8]  [50/60]  eta: 0:00:02  lr: 0.000050  loss: 0.1738 (0.1761)  loss_classifier: 0.0216 (0.0240)  loss_box_reg: 0.0293 (0.0344)  loss_mask: 0.1138 (0.1143)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0019 (0.0027)  time: 0.2163  data: 0.0144  max mem: 2825
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1673 (0.1755)  loss_classifier: 0.0208 (0.0242)  loss_box_reg: 0.0267 (0.0339)  loss_mask: 0.1106 (0.1139)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0027)  time: 0.2153  data: 0.0153  max mem: 2825
# Epoch: [8] Total time: 0:00:13 (0.2188 s / it)
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.1673 (0.1755)  loss_classifier: 0.0208 (0.0242)  loss_box_reg: 0.0267 (0.0339)  loss_mask: 0.1106 (0.1139)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0017 (0.
  loss_objectness: 0.0006 (0.0008)  loss_rpn_box_reg: 0.0019 (0.0029)  time: 0.2150  data: 0.0166  max mem: 2825
# Epoch: [9]  [40/60]  eta: 0:00:04  lr: 0.000005  loss: 0.1641 (0.1787)  loss_classifier: 0.0221 (0.0249)  loss_box_reg: 0.0286 (0.0353)  loss_mask: 0.1098 (0.1148)  loss_objectness: 0.0006 (0.0008)  loss_rpn_box_reg: 0.0019 (0.0029)  time: 0.2150  data: 0.0166  max mem: 2825
# Epoch: [9]  [50/60]  eta: 0:00:02  lr: 0.000005  loss: 0.1636 (0.1766)  loss_classifier: 0.0215 (0.0246)  loss_box_reg: 0.0238 (0.0342)  loss_mask: 0.1094 (0.1142)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0028)  time: 0.2220  data: 0.0162  max mem: 2825
# Epoch: [9]  [50/60]  eta: 0:00:02  lr: 0.000005  loss: 0.1636 (0.1766)  loss_classifier: 0.0215 (0.0246)  loss_box_reg: 0.0238 (0.0342)  loss_mask: 0.1094 (0.1142)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0028)  time: 0.2220  data: 0.0162  max mem: 2825
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1659 (0.1758)  loss_classifier: 0.0239 (0.0251)  loss_box_reg: 0.0320 (0.0338)  loss_mask: 0.1045 (0.1133)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0023 (0.0028)  time: 0.2288  data: 0.0162  max mem: 2825
# Epoch: [9] Total time: 0:00:13 (0.2195 s / it)
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.1659 (0.1758)  loss_classifier: 0.0239 (0.0251)  loss_box_reg: 0.0320 (0.0338)  loss_mask: 0.1045 (0.1133)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0023 (0.0028)  time: 0.2288  data: 0.0162  max mem: 2825
# Epoch: [9] Total time: 0:00:13 (0.2195 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:02  model_time: 0.0363 (0.0363)  evaluator_time: 0.0000 (0.0000)  time: 0.0478  data: 0.0112  max mem: 2825
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:02  model_time: 0.0363 (0.0363)  evaluator_time: 0.0000 (0.0000)  time: 0.0478  data: 0.0112  max mem: 2825
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0401 (0.0421)  evaluator_time: 0.0000 (0.0033)  time: 0.0484  data: 0.0056  max mem: 2825
# Test: Total time: 0:00:02 (0.0521 s / it)
# Averaged stats: model_time: 0.0401 (0.0421)  evaluator_time: 0.0000 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.796
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.991
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.628
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.746
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.991
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.892
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.796
# That's it!
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0401 (0.0421)  evaluator_time: 0.0000 (0.0033)  time: 0.0484  data: 0.0056  max mem: 2825
# Test: Total time: 0:00:02 (0.0521 s / it)
# Averaged stats: model_time: 0.0401 (0.0421)  evaluator_time: 0.0000 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.796
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.991
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.628
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.333
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.746
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.991
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.892
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.796
# That's it!

# %% [markdown]
# So after one epoch of training, we obtain a COCO-style mAP \> 50, and a
# mask mAP of 65.
#
# But what do the predictions look like? Let's take one image in the
# dataset and verify

# %%
import pandas as pd
from engine import evaluate
import torch

def compare_models(model1, model2, data_loader, device, model1_name="Model 1", model2_name="Model 2"):
    """
    Evaluate and compare two models on the same dataset
    
    Args:
        model1: First model to evaluate
        model2: Second model to evaluate  
        data_loader: DataLoader for evaluation dataset
        device: Device to run evaluation on
        model1_name: Name for the first model (for display)
        model2_name: Name for the second model (for display)
    """
    print(f"Evaluating {model1_name}...")
    model1.eval()
    # Capture evaluation results for model 1
    import io
    import sys
    from contextlib import redirect_stdout
    
    # Redirect stdout to capture evaluation metrics
    f1 = io.StringIO()
    with redirect_stdout(f1):
        eval_results_1 = evaluate(model1, data_loader, device=device)
    model1_output = f1.getvalue()
    
    print(f"Evaluating {model2_name}...")
    model2.eval()
    f2 = io.StringIO()
    with redirect_stdout(f2):
        eval_results_2 = evaluate(model2, data_loader, device=device)
    model2_output = f2.getvalue()
    
    # Extract metrics from the evaluation results
    def extract_metrics(eval_results, output_text):
        metrics = {}
        
        # Try to extract mAP values from COCO evaluator if available
        if hasattr(eval_results, 'coco_eval') and eval_results.coco_eval is not None:
            coco_eval = eval_results.coco_eval['bbox']
            metrics['mAP@0.5:0.95'] = float(coco_eval.stats[0]) if coco_eval.stats[0] >= 0 else 0.0
            metrics['mAP@0.5'] = float(coco_eval.stats[1]) if coco_eval.stats[1] >= 0 else 0.0
            metrics['mAP@0.75'] = float(coco_eval.stats[2]) if coco_eval.stats[2] >= 0 else 0.0
            metrics['mAP_small'] = float(coco_eval.stats[3]) if coco_eval.stats[3] >= 0 else 0.0
            metrics['mAP_medium'] = float(coco_eval.stats[4]) if coco_eval.stats[4] >= 0 else 0.0
            metrics['mAP_large'] = float(coco_eval.stats[5]) if coco_eval.stats[5] >= 0 else 0.0
            
            # Mask mAP if available
            if 'segm' in eval_results.coco_eval:
                coco_eval_mask = eval_results.coco_eval['segm']
                metrics['Mask_mAP@0.5:0.95'] = float(coco_eval_mask.stats[0]) if coco_eval_mask.stats[0] >= 0 else 0.0
                metrics['Mask_mAP@0.5'] = float(coco_eval_mask.stats[1]) if coco_eval_mask.stats[1] >= 0 else 0.0
        else:
            # Fallback: parse from output text
            lines = output_text.split('\n')
            for line in lines:
                if 'Average Precision' in line and 'IoU=0.50:0.95' in line:
                    try:
                        metrics['mAP@0.5:0.95'] = float(line.split('=')[-1].strip())
                    except:
                        metrics['mAP@0.5:0.95'] = 0.0
                elif 'Average Precision' in line and 'IoU=0.50' in line:
                    try:
                        metrics['mAP@0.5'] = float(line.split('=')[-1].strip())
                    except:
                        metrics['mAP@0.5'] = 0.0
        
        return metrics
    
    # Extract metrics for both models
    metrics1 = extract_metrics(eval_results_1, model1_output)
    metrics2 = extract_metrics(eval_results_2, model2_output)
    
    # Create comparison DataFrame
    comparison_data = []
    all_metrics = set(metrics1.keys()) | set(metrics2.keys())
    
    for metric in sorted(all_metrics):
        val1 = metrics1.get(metric, 0.0)
        val2 = metrics2.get(metric, 0.0)
        
        # Determine which is better (higher is better for mAP)
        if val1 > val2:
            better = model1_name
            diff = val1 - val2
        elif val2 > val1:
            better = model2_name  
            diff = val2 - val1
        else:
            better = "Tie"
            diff = 0.0
            
        comparison_data.append({
            'Metric': metric,
            model1_name: f"{val1:.4f}",
            model2_name: f"{val2:.4f}", 
            'Better Model': better,
            'Difference': f"{diff:.4f}"
        })
    
    df = pd.DataFrame(comparison_data)
    
    # Display results
    print("\n" + "="*80)
    print("MODEL COMPARISON RESULTS")
    print("="*80)
    print(df.to_string(index=False))
    print("\n" + "="*80)
    
    # Determine overall winner based on main mAP metric
    main_metric = 'mAP@0.5:0.95'
    if main_metric in metrics1 and main_metric in metrics2:
        if metrics1[main_metric] > metrics2[main_metric]:
            winner = model1_name
            winner_score = metrics1[main_metric]
        elif metrics2[main_metric] > metrics1[main_metric]:
            winner = model2_name
            winner_score = metrics2[main_metric]
        else:
            winner = "Tie"
            winner_score = metrics1[main_metric]
        
        print(f"🏆 OVERALL WINNER: {winner}")
        if winner != "Tie":
            print(f"   Best {main_metric}: {winner_score:.4f}")
    else:
        print("⚠️  Could not determine overall winner - main mAP metric not available")
    
    print("="*80)
    
    return df, metrics1, metrics2

# %%
import matplotlib.pyplot as plt

from torchvision.utils import draw_bounding_boxes, draw_segmentation_masks


image = read_image("data/PennFudanPed/PNGImages/FudanPed00046.png")
eval_transform = get_transform(train=False)

model.eval()
with torch.no_grad():
    x = eval_transform(image)
    # convert RGBA -> RGB and move to device
    x = x[:3, ...].to(device)
    predictions = model([x, ])
    pred = predictions[0]


image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
image = image[:3, ...]
pred_labels = [f"pedestrian: {score:.3f}" for label, score in zip(pred["labels"], pred["scores"])]
pred_boxes = pred["boxes"].long()
output_image = draw_bounding_boxes(image, pred_boxes, pred_labels, colors="red")

masks = (pred["masks"] > 0.7).squeeze(1)
output_image = draw_segmentation_masks(output_image, masks, alpha=0.5, colors="blue")


plt.figure(figsize=(12, 12))
plt.imshow(output_image.permute(1, 2, 0))

# %% [markdown]
# The results look good!
#
# Wrapping up
# ===========
#
# In this tutorial, you have learned how to create your own training
# pipeline for object detection models on a custom dataset. For that, you
# wrote a `torch.utils.data.Dataset`{.interpreted-text role="class"} class
# that returns the images and the ground truth boxes and segmentation
# masks. You also leveraged a Mask R-CNN model pre-trained on COCO
# train2017 in order to perform transfer learning on this new dataset.
#
# For a more complete example, which includes multi-machine / multi-GPU
# training, check `references/detection/train.py`, which is present in the
# torchvision repository.

# %% [markdown]
# #### Dectetion Frameworks
#
# https://github.com/open-mmlab/mmdetection/blob/main/demo/MMDet_InstanceSeg_Tutorial.ipynb

# %% [markdown]
# # Exercise

# %%
# Exercise: Simple Model Modification
# 
# Your task: Modify the learning rate in the training code above from 0.005 to 0.001
# 
# Find the line that says:
# optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
# 
# Change lr=0.005 to lr=0.001 and observe how it affects training convergence

print("Exercise: Change the learning rate from 0.005 to 0.001 in the optimizer above!")
print("Hint: Look for the line with 'lr=0.005' in the training code cell.")
# Out:
# Exercise: Change the learning rate from 0.005 to 0.001 in the optimizer above!
# Hint: Look for the line with 'lr=0.005' in the training code cell.

# %% [markdown]
# ## Exercise Solution
#
#
# <details>
#   <summary>Click to show/hide the solution</summary>
#
# ```python
# optimizer = torch.optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=0.0005)
# ```
#
#
# **What happens?**
# - Lower learning rate (0.001) makes the model learn more slowly but more stably
# - Training loss decreases more gradually
# - May need more epochs to reach the same performance
# - Often leads to better final accuracy and less overfitting
#
# </details>

# %%
# get the model using our helper function
new_model = get_model_instance_segmentation(num_classes)

# move model to the right device
new_model.to(device)

# optimizer = ##### YOUR CODE HERE
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)

# let's train it just for 10 epochs
num_epochs = 10

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(new_model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(new_model, data_loader_test, device=device)
# Out:
# c:\WUR\ML_Ricardo_Tutorials\Computer Vision\engine.py:30: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# Epoch: [0]  [ 0/60]  eta: 0:00:19  lr: 0.000090  loss: 2.9453 (2.9453)  loss_classifier: 0.5674 (0.5674)  loss_box_reg: 0.2910 (0.2910)  loss_mask: 2.0664 (2.0664)  loss_objectness: 0.0157 (0.0157)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 0.3180  data: 0.0156  max mem: 2825
# Epoch: [0]  [10/60]  eta: 0:00:11  lr: 0.000936  loss: 2.9741 (2.9516)  loss_classifier: 0.5576 (0.5548)  loss_box_reg: 0.2910 (0.3137)  loss_mask: 2.0664 (2.0600)  loss_objectness: 0.0157 (0.0179)  loss_rpn_box_reg: 0.0051 (0.0051)  time: 0.2226  data: 0.0171  max mem: 2825
# Epoch: [0]  [20/60]  eta: 0:00:08  lr: 0.001783  loss: 2.9741 (2.9992)  loss_classifier: 0.5536 (0.5569)  loss_box_reg: 0.2555 (0.2914)  loss_mask: 2.1444 (2.1249)  loss_objectness: 0.0174 (0.0213)  loss_rpn_box_reg: 0.0032 (0.0046)  time: 0.2089  data: 0.0158  max mem: 2825
# Epoch: [0]  [30/60]  eta: 0:00:06  lr: 0.002629  loss: 2.9653 (2.9851)  loss_classifier: 0.5447 (0.5532)  loss_box_reg: 0.3223 (0.3002)  loss_mask: 2.1014 (2.1040)  loss_objectness: 0.0193 (0.0232)  loss_rpn_box_reg: 0.0032 (0.0045)  time: 0.2152  data: 0.0143  max mem: 2877
# Epoch: [0]  [40/60]  eta: 0:00:04  lr: 0.003476  loss: 2.9653 (2.9881)  loss_classifier: 0.5475 (0.5524)  loss_box_reg: 0.3223 (0.2979)  loss_mask: 2.0411 (2.1084)  loss_objectness: 0.0290 (0.0249)  loss_rpn_box_reg: 0.0037 (0.0046)  time: 0.2209  data: 0.0147  max mem: 2958
# Epoch: [0]  [50/60]  eta: 0:00:02  lr: 0.004323  loss: 2.9177 (2.9833)  loss_classifier: 0.5519 (0.5521)  loss_box_reg: 0.2568 (0.2887)  loss_mask: 2.0614 (2.1137)  loss_objectness: 0.0190 (0.0244)  loss_rpn_box_reg: 0.0030 (0.0044)  time: 0.2135  data: 0.0134  max mem: 2958
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.9058 (2.9584)  loss_classifier: 0.5552 (0.5539)  loss_box_reg: 0.3043 (0.2918)  loss_mask: 2.0409 (2.0841)  loss_objectness: 0.0189 (0.0240)  loss_rpn_box_reg: 0.0030 (0.0046)  time: 0.2093  data: 0.0123  max mem: 2958
# Epoch: [0] Total time: 0:00:12 (0.2153 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1098 (0.1098)  evaluator_time: 0.0551 (0.0551)  time: 0.1876  data: 0.0214  max mem: 2958
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0942 (0.0980)  evaluator_time: 0.0335 (0.0397)  time: 0.1383  data: 0.0088  max mem: 2958
# Test: Total time: 0:00:07 (0.1460 s / it)
# Averaged stats: model_time: 0.0942 (0.0980)  evaluator_time: 0.0335 (0.0397)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [1]  [ 0/60]  eta: 0:00:13  lr: 0.005000  loss: 3.6577 (3.6577)  loss_classifier: 0.5613 (0.5613)  loss_box_reg: 0.2749 (0.2749)  loss_mask: 2.7600 (2.7600)  loss_objectness: 0.0591 (0.0591)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 0.2174  data: 0.0251  max mem: 2958
# Epoch: [1]  [10/60]  eta: 0:00:10  lr: 0.005000  loss: 3.0735 (3.0970)  loss_classifier: 0.5525 (0.5535)  loss_box_reg: 0.2694 (0.2805)  loss_mask: 2.1399 (2.2326)  loss_objectness: 0.0217 (0.0266)  loss_rpn_box_reg: 0.0028 (0.0038)  time: 0.2061  data: 0.0162  max mem: 2958
# Epoch: [1]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 3.0735 (3.0738)  loss_classifier: 0.5525 (0.5591)  loss_box_reg: 0.2692 (0.2985)  loss_mask: 2.0994 (2.1879)  loss_objectness: 0.0197 (0.0237)  loss_rpn_box_reg: 0.0036 (0.0046)  time: 0.2075  data: 0.0148  max mem: 2958
# Epoch: [1]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 3.0986 (3.0754)  loss_classifier: 0.5597 (0.5602)  loss_box_reg: 0.3018 (0.3053)  loss_mask: 2.2013 (2.1815)  loss_objectness: 0.0148 (0.0235)  loss_rpn_box_reg: 0.0046 (0.0048)  time: 0.2208  data: 0.0135  max mem: 3117
# Epoch: [1]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.8647 (2.9953)  loss_classifier: 0.5577 (0.5580)  loss_box_reg: 0.2908 (0.3023)  loss_mask: 2.0470 (2.1083)  loss_objectness: 0.0114 (0.0220)  loss_rpn_box_reg: 0.0046 (0.0047)  time: 0.2198  data: 0.0119  max mem: 3117
# Epoch: [1]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 2.7812 (2.9818)  loss_classifier: 0.5447 (0.5551)  loss_box_reg: 0.2908 (0.3001)  loss_mask: 1.9493 (2.1017)  loss_objectness: 0.0096 (0.0202)  loss_rpn_box_reg: 0.0033 (0.0047)  time: 0.2153  data: 0.0130  max mem: 3117
# Epoch: [1]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.7682 (2.9508)  loss_classifier: 0.5482 (0.5535)  loss_box_reg: 0.2765 (0.2950)  loss_mask: 1.9828 (2.0772)  loss_objectness: 0.0117 (0.0204)  loss_rpn_box_reg: 0.0027 (0.0047)  time: 0.2176  data: 0.0148  max mem: 3117
# Epoch: [1] Total time: 0:00:12 (0.2154 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.1000 (0.1000)  evaluator_time: 0.0576 (0.0576)  time: 0.1637  data: 0.0061  max mem: 3117
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0968 (0.0971)  evaluator_time: 0.0335 (0.0382)  time: 0.1387  data: 0.0076  max mem: 3117
# Test: Total time: 0:00:07 (0.1437 s / it)
# Averaged stats: model_time: 0.0968 (0.0971)  evaluator_time: 0.0335 (0.0382)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [ 0/60]  eta: 0:00:10  lr: 0.005000  loss: 2.7797 (2.7797)  loss_classifier: 0.5704 (0.5704)  loss_box_reg: 0.2251 (0.2251)  loss_mask: 1.9695 (1.9695)  loss_objectness: 0.0127 (0.0127)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 0.1738  data: 0.0080  max mem: 3117
# Epoch: [2]  [10/60]  eta: 0:00:10  lr: 0.005000  loss: 3.0710 (2.9960)  loss_classifier: 0.5704 (0.5625)  loss_box_reg: 0.2967 (0.2997)  loss_mask: 2.1141 (2.1066)  loss_objectness: 0.0238 (0.0231)  loss_rpn_box_reg: 0.0032 (0.0041)  time: 0.2083  data: 0.0137  max mem: 3117
# Epoch: [2]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 2.9671 (2.9327)  loss_classifier: 0.5530 (0.5575)  loss_box_reg: 0.2723 (0.2845)  loss_mask: 2.0744 (2.0637)  loss_objectness: 0.0219 (0.0227)  loss_rpn_box_reg: 0.0045 (0.0044)  time: 0.2075  data: 0.0135  max mem: 3117
# Epoch: [2]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 2.9309 (2.9846)  loss_classifier: 0.5530 (0.5580)  loss_box_reg: 0.2101 (0.2989)  loss_mask: 2.0940 (2.1001)  loss_objectness: 0.0219 (0.0233)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 0.2121  data: 0.0141  max mem: 3117
# Epoch: [2]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.6821 (2.8941)  loss_classifier: 0.5480 (0.5533)  loss_box_reg: 0.2373 (0.2812)  loss_mask: 1.9142 (2.0335)  loss_objectness: 0.0160 (0.0219)  loss_rpn_box_reg: 0.0032 (0.0041)  time: 0.2105  data: 0.0157  max mem: 3117
# Epoch: [2]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 2.7364 (2.9363)  loss_classifier: 0.5457 (0.5531)  loss_box_reg: 0.2381 (0.2867)  loss_mask: 1.9042 (2.0699)  loss_objectness: 0.0201 (0.0221)  loss_rpn_box_reg: 0.0031 (0.0045)  time: 0.2108  data: 0.0149  max mem: 3117
# Epoch: [2]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 3.0685 (2.9397)  loss_classifier: 0.5537 (0.5543)  loss_box_reg: 0.3478 (0.2950)  loss_mask: 2.2276 (2.0634)  loss_objectness: 0.0201 (0.0223)  loss_rpn_box_reg: 0.0056 (0.0047)  time: 0.2200  data: 0.0138  max mem: 3117
# Epoch: [2] Total time: 0:00:12 (0.2130 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.1040 (0.1040)  evaluator_time: 0.0463 (0.0463)  time: 0.1671  data: 0.0169  max mem: 3117
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0871 (0.0942)  evaluator_time: 0.0349 (0.0374)  time: 0.1349  data: 0.0108  max mem: 3117
# Test: Total time: 0:00:07 (0.1407 s / it)
# Averaged stats: model_time: 0.0871 (0.0942)  evaluator_time: 0.0349 (0.0374)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [3]  [ 0/60]  eta: 0:00:12  lr: 0.005000  loss: 3.5280 (3.5280)  loss_classifier: 0.5653 (0.5653)  loss_box_reg: 0.3172 (0.3172)  loss_mask: 2.6092 (2.6092)  loss_objectness: 0.0334 (0.0334)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 0.2003  data: 0.0118  max mem: 3117
# Epoch: [3]  [10/60]  eta: 0:00:10  lr: 0.005000  loss: 3.0645 (3.0981)  loss_classifier: 0.5515 (0.5588)  loss_box_reg: 0.2772 (0.3008)  loss_mask: 2.2108 (2.2048)  loss_objectness: 0.0197 (0.0289)  loss_rpn_box_reg: 0.0035 (0.0048)  time: 0.2162  data: 0.0139  max mem: 3117
# Epoch: [3]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 3.0600 (3.0444)  loss_classifier: 0.5510 (0.5615)  loss_box_reg: 0.2772 (0.3043)  loss_mask: 2.1877 (2.1471)  loss_objectness: 0.0197 (0.0265)  loss_rpn_box_reg: 0.0031 (0.0050)  time: 0.2180  data: 0.0141  max mem: 3117
# Epoch: [3]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 2.8783 (2.9913)  loss_classifier: 0.5510 (0.5574)  loss_box_reg: 0.2919 (0.2908)  loss_mask: 2.0655 (2.1124)  loss_objectness: 0.0209 (0.0262)  loss_rpn_box_reg: 0.0030 (0.0045)  time: 0.2171  data: 0.0141  max mem: 3117
# Epoch: [3]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.9274 (2.9940)  loss_classifier: 0.5447 (0.5551)  loss_box_reg: 0.2919 (0.2987)  loss_mask: 2.0365 (2.1102)  loss_objectness: 0.0173 (0.0254)  loss_rpn_box_reg: 0.0039 (0.0047)  time: 0.2126  data: 0.0148  max mem: 3117
# Epoch: [3]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 2.9351 (2.9831)  loss_classifier: 0.5482 (0.5542)  loss_box_reg: 0.3043 (0.2968)  loss_mask: 2.0757 (2.1027)  loss_objectness: 0.0196 (0.0251)  loss_rpn_box_reg: 0.0034 (0.0044)  time: 0.2105  data: 0.0143  max mem: 3117
# Epoch: [3]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.8057 (2.9497)  loss_classifier: 0.5482 (0.5550)  loss_box_reg: 0.2917 (0.2945)  loss_mask: 1.9844 (2.0715)  loss_objectness: 0.0143 (0.0242)  loss_rpn_box_reg: 0.0029 (0.0045)  time: 0.2153  data: 0.0139  max mem: 3117
# Epoch: [3] Total time: 0:00:12 (0.2155 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00

# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [5]  [ 0/60]  eta: 0:00:14  lr: 0.005000  loss: 2.9683 (2.9683)  loss_classifier: 0.5272 (0.5272)  loss_box_reg: 0.2257 (0.2257)  loss_mask: 2.2103 (2.2103)  loss_objectness: 0.0034 (0.0034)  loss_rpn_box_reg: 0.0017 (0.0017)  time: 0.2421  data: 0.0260  max mem: 3117
# Epoch: [5]  [10/60]  eta: 0:00:10  lr: 0.005000  loss: 3.0398 (2.9808)  loss_classifier: 0.5496 (0.5510)  loss_box_reg: 0.2949 (0.2938)  loss_mask: 2.0908 (2.1015)  loss_objectness: 0.0217 (0.0272)  loss_rpn_box_reg: 0.0053 (0.0073)  time: 0.2180  data: 0.0164  max mem: 3117
# Epoch: [5]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 3.0180 (3.0136)  loss_classifier: 0.5538 (0.5537)  loss_box_reg: 0.2610 (0.3049)  loss_mask: 2.0440 (2.1262)  loss_objectness: 0.0152 (0.0232)  loss_rpn_box_reg: 0.0046 (0.0055)  time: 0.2177  data: 0.0164  max mem: 3117
# Epoch: [5]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 2.9749 (3.0106)  loss_classifier: 0.5538 (0.5532)  loss_box_reg: 0.2641 (0.3070)  loss_mask: 1.9757 (2.1227)  loss_objectness: 0.0164 (0.0224)  loss_rpn_box_reg: 0.0028 (0.0052)  time: 0.2146  data: 0.0153  max mem: 3117
# Epoch: [5]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.8363 (2.9821)  loss_classifier: 0.5545 (0.5535)  loss_box_reg: 0.2641 (0.2989)  loss_mask: 2.0192 (2.0995)  loss_objectness: 0.0253 (0.0248)  loss_rpn_box_reg: 0.0035 (0.0054)  time: 0.2109  data: 0.0139  max mem: 3117
# Epoch: [5]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 2.9508 (2.9814)  loss_classifier: 0.5545 (0.5542)  loss_box_reg: 0.2582 (0.2979)  loss_mask: 2.0480 (2.1002)  loss_objectness: 0.0279 (0.0241)  loss_rpn_box_reg: 0.0034 (0.0050)  time: 0.2116  data: 0.0160  max mem: 3117
# Epoch: [5]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.9508 (2.9757)  loss_classifier: 0.5580 (0.5558)  loss_box_reg: 0.2640 (0.2950)  loss_mask: 2.0231 (2.0973)  loss_objectness: 0.0176 (0.0230)  loss_rpn_box_reg: 0.0023 (0.0047)  time: 0.2183  data: 0.0168  max mem: 3117
# Epoch: [5] Total time: 0:00:12 (0.2151 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.1156 (0.1156)  evaluator_time: 0.0455 (0.0455)  time: 0.1611  data: 0.0000  max mem: 3117
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0907 (0.0966)  evaluator_time: 0.0318 (0.0370)  time: 0.1334  data: 0.0077  max mem: 3117
# Test: Total time: 0:00:07 (0.1407 s / it)
# Averaged stats: model_time: 0.0907 (0.0966)  evaluator_time: 0.0318 (0.0370)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [6]  [ 0/60]  eta: 0:00:15  lr: 0.005000  loss: 3.0325 (3.0325)  loss_classifier: 0.5206 (0.5206)  loss_box_reg: 0.2028 (0.2028)  loss_mask: 2.2886 (2.2886)  loss_objectness: 0.0177 (0.0177)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 0.2500  data: 0.0166  max mem: 3117
# Epoch: [6]  [10/60]  eta: 0:00:10  lr: 0.005000  loss: 3.0325 (3.0279)  loss_classifier: 0.5376 (0.5429)  loss_box_reg: 0.2564 (0.2638)  loss_mask: 2.2155 (2.2033)  loss_objectness: 0.0103 (0.0152)  loss_rpn_box_reg: 0.0026 (0.0027)  time: 0.2065  data: 0.0127  max mem: 3117
# Epoch: [6]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 3.0401 (3.0490)  loss_classifier: 0.5435 (0.5542)  loss_box_reg: 0.2751 (0.2888)  loss_mask: 2.2131 (2.1799)  loss_objectness: 0.0209 (0.0229)  loss_rpn_box_reg: 0.0022 (0.0032)  time: 0.2071  data: 0.0140  max mem: 3117
# Epoch: [6]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 2.8958 (2.9596)  loss_classifier: 0.5498 (0.5543)  loss_box_reg: 0.2752 (0.2801)  loss_mask: 2.0193 (2.0976)  loss_objectness: 0.0196 (0.0239)  loss_rpn_box_reg: 0.0040 (0.0037)  time: 0.2089  data: 0.0138  max mem: 3117
# Epoch: [6]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.7213 (2.9442)  loss_classifier: 0.5535 (0.5567)  loss_box_reg: 0.2845 (0.2901)  loss_mask: 1.9027 (2.0667)  loss_objectness: 0.0177 (0.0264)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 0.2086  data: 0.0134  max mem: 3117
# Epoch: [6]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 2.8808 (2.9353)  loss_classifier: 0.5491 (0.5530)  loss_box_reg: 0.2886 (0.2895)  loss_mask: 1.9639 (2.0626)  loss_objectness: 0.0212 (0.0258)  loss_rpn_box_reg: 0.0030 (0.0045)  time: 0.2158  data: 0.0150  max mem: 3117
# Epoch: [6]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.9629 (2.9422)  loss_classifier: 0.5389 (0.5537)  loss_box_reg: 0.2886 (0.2927)  loss_mask: 1.9837 (2.0663)  loss_objectness: 0.0204 (0.0248)  loss_rpn_box_reg: 0.0030 (0.0047)  time: 0.2136  data: 0.0148  max mem: 3117
# Epoch: [6] Total time: 0:00:12 (0.2111 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:07  model_time: 0.0997 (0.0997)  evaluator_time: 0.0503 (0.0503)  time: 0.1501  data: 0.0000  max mem: 3117
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0863 (0.0931)  evaluator_time: 0.0339 (0.0385)  time: 0.1341  data: 0.0064  max mem: 3117
# Test: Total time: 0:00:06 (0.1393 s / it)
# Averaged stats: model_time: 0.0863 (0.0931)  evaluator_time: 0.0339 (0.0385)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [7]  [ 0/60]  eta: 0:00:09  lr: 0.005000  loss: 2.8468 (2.8468)  loss_classifier: 0.5128 (0.5128)  loss_box_reg: 0.0972 (0.0972)  loss_mask: 2.2236 (2.2236)  loss_objectness: 0.0116 (0.0116)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 0.1664  data: 0.0171  max mem: 3117
# Epoch: [7]  [10/60]  eta: 0:00:09  lr: 0.005000  loss: 3.0529 (2.8859)  loss_classifier: 0.5317 (0.5314)  loss_box_reg: 0.2287 (0.2332)  loss_mask: 2.1457 (2.0981)  loss_objectness: 0.0116 (0.0197)  loss_rpn_box_reg: 0.0022 (0.0035)  time: 0.1969  data: 0.0084  max mem: 3117
# Epoch: [7]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 3.0455 (2.9558)  loss_classifier: 0.5387 (0.5470)  loss_box_reg: 0.2942 (0.2850)  loss_mask: 2.0541 (2.0983)  loss_objectness: 0.0163 (0.0212)  loss_rpn_box_reg: 0.0037 (0.0043)  time: 0.2076  data: 0.0110  max mem: 3117
# Epoch: [7]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 2.9925 (2.9506)  loss_classifier: 0.5635 (0.5534)  loss_box_reg: 0.3259 (0.2911)  loss_mask: 2.0350 (2.0800)  loss_objectness: 0.0211 (0.0217)  loss_rpn_box_reg: 0.0051 (0.0044)  time: 0.2182  data: 0.0142  max mem: 3117
# Epoch: [7]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.9371 (2.9654)  loss_classifier: 0.5652 (0.5556)  loss_box_reg: 0.3163 (0.2997)  loss_mask: 2.0350 (2.0836)  loss_objectness: 0.0211 (0.0218)  loss_rpn_box_reg: 0.0030 (0.0047)  time: 0.2173  data: 0.0148  max mem: 3117
# Epoch: [7]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 2.8608 (2.9621)  loss_classifier: 0.5617 (0.5545)  loss_box_reg: 0.2496 (0.2941)  loss_mask: 2.0444 (2.0859)  loss_objectness: 0.0202 (0.0230)  loss_rpn_box_reg: 0.0030 (0.0046)  time: 0.2126  data: 0.0158  max mem: 3117
# Epoch: [7]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.9133 (2.9680)  loss_classifier: 0.5528 (0.5546)  loss_box_reg: 0.2429 (0.2924)  loss_mask: 2.0656 (2.0928)  loss_objectness: 0.0226 (0.0237)  loss_rpn_box_reg: 0.0035 (0.0045)  time: 0.2174  data: 0.0161  max mem: 3117
# Epoch: [7] Total time: 0:00:12 (0.2128 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0831 (0.0831)  evaluator_time: 0.0671 (0.0671)  time: 0.1668  data: 0.0166  max mem: 3117
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0835 (0.0914)  evaluator_time: 0.0320 (0.0391)  time: 0.1328  data: 0.0099  max mem: 3117
# Test: Total time: 0:00:06 (0.1391 s / it)
# Averaged stats: model_time: 0.0835 (0.0914)  evaluator_time: 0.0320 (0.0391)
# Accumulating evaluation results...
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [8]  [ 0/60]  eta: 0:00:14  lr: 0.005000  loss: 2.8214 (2.8214)  loss_classifier: 0.5544 (0.5544)  loss_box_reg: 0.3392 (0.3392)  loss_mask: 1.9079 (1.9079)  loss_objectness: 0.0165 (0.0165)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 0.2493  data: 0.0161  max mem: 3117
# Epoch: [8]  [10/60]  eta: 0:00:10  lr: 0.005000  loss: 3.0738 (3.0476)  loss_classifier: 0.5544 (0.5601)  loss_box_reg: 0.3392 (0.3408)  loss_mask: 2.0691 (2.1181)  loss_objectness: 0.0233 (0.0246)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 0.2091  data: 0.0114  max mem: 3117
# Epoch: [8]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 3.0738 (3.0279)  loss_classifier: 0.5563 (0.5589)  loss_box_reg: 0.3195 (0.3361)  loss_mask: 2.1016 (2.1050)  loss_objectness: 0.0202 (0.0229)  loss_rpn_box_reg: 0.0043 (0.0050)  time: 0.2103  data: 0.0121  max mem: 3117
# Epoch: [8]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 2.8931 (2.9604)  loss_classifier: 0.5565 (0.5570)  loss_box_reg: 0.2198 (0.2968)  loss_mask: 2.1016 (2.0824)  loss_objectness: 0.0105 (0.0199)  loss_rpn_box_reg: 0.0027 (0.0043)  time: 0.2146  data: 0.0127  max mem: 3117
# Epoch: [8]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.9393 (2.9753)  loss_classifier: 0.5567 (0.5585)  loss_box_reg: 0.2367 (0.3009)  loss_mask: 2.1140 (2.0889)  loss_objectness: 0.0152 (0.0226)  loss_rpn_box_reg: 0.0027 (0.0044)  time: 0.2169  data: 0.0145  max mem: 3117
# Epoch: [8]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 3.0007 (2.9724)  loss_classifier: 0.5432 (0.5543)  loss_box_reg: 0.2897 (0.2943)  loss_mask: 2.1421 (2.0982)  loss_objectness: 0.0157 (0.0212)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 0.2146  data: 0.0156  max mem: 3117
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.9993 (2.9634)  loss_classifier: 0.5432 (0.5556)  loss_box_reg: 0.2712 (0.2968)  loss_mask: 2.0597 (2.0842)  loss_objectness: 0.0197 (0.0221)  loss_rpn_box_reg: 0.0040 (0.0046)  time: 0.2116  data: 0.0156  max mem: 3117
# Epoch: [8] Total time: 0:00:12 (0.2139 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:08  model_time: 0.0994 (0.0994)  evaluator_time: 0.0605 (0.0605)  time: 0.1765  data: 0.0166  max mem: 3117
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1000 (0.0954)  evaluator_time: 0.0334 (0.0385)  time: 0.1408  data: 0.0062  max mem: 3117
# Test: Total time: 0:00:07 (0.1430 s / it)
# Averaged stats: model_time: 0.1000 (0.0954)  evaluator_time: 0.0334 (0.0385)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [9]  [ 0/60]  eta: 0:00:15  lr: 0.005000  loss: 3.5078 (3.5078)  loss_classifier: 0.5926 (0.5926)  loss_box_reg: 0.5960 (0.5960)  loss_mask: 2.2559 (2.2559)  loss_objectness: 0.0592 (0.0592)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 0.2660  data: 0.0159  max mem: 3117
# Epoch: [9]  [10/60]  eta: 0:00:10  lr: 0.005000  loss: 3.2051 (3.1770)  loss_classifier: 0.5634 (0.5633)  loss_box_reg: 0.3373 (0.3335)  loss_mask: 2.2838 (2.2486)  loss_objectness: 0.0203 (0.0270)  loss_rpn_box_reg: 0.0041 (0.0046)  time: 0.2092  data: 0.0155  max mem: 3117
# Epoch: [9]  [20/60]  eta: 0:00:08  lr: 0.005000  loss: 3.0129 (3.0228)  loss_classifier: 0.5533 (0.5600)  loss_box_reg: 0.2385 (0.3011)  loss_mask: 2.0716 (2.1345)  loss_objectness: 0.0199 (0.0229)  loss_rpn_box_reg: 0.0024 (0.0043)  time: 0.2055  data: 0.0144  max mem: 3117
# Epoch: [9]  [30/60]  eta: 0:00:06  lr: 0.005000  loss: 2.8739 (2.9806)  loss_classifier: 0.5523 (0.5566)  loss_box_reg: 0.2672 (0.2991)  loss_mask: 1.9907 (2.0976)  loss_objectness: 0.0201 (0.0227)  loss_rpn_box_reg: 0.0024 (0.0046)  time: 0.2093  data: 0.0136  max mem: 3117
# Epoch: [9]  [40/60]  eta: 0:00:04  lr: 0.005000  loss: 2.8414 (2.9826)  loss_classifier: 0.5489 (0.5544)  loss_box_reg: 0.2869 (0.2916)  loss_mask: 2.0106 (2.1105)  loss_objectness: 0.0199 (0.0220)  loss_rpn_box_reg: 0.0032 (0.0041)  time: 0.2044  data: 0.0143  max mem: 3117
# Epoch: [9]  [50/60]  eta: 0:00:02  lr: 0.005000  loss: 3.0320 (3.0049)  loss_classifier: 0.5492 (0.5552)  loss_box_reg: 0.2910 (0.2984)  loss_mask: 2.1423 (2.1233)  loss_objectness: 0.0192 (0.0233)  loss_rpn_box_reg: 0.0032 (0.0046)  time: 0.2130  data: 0.0142  max mem: 3117
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 2.9248 (2.9731)  loss_classifier: 0.5564 (0.5554)  loss_box_reg: 0.2996 (0.2965)  loss_mask: 2.0635 (2.0943)  loss_objectness: 0.0187 (0.0223)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 0.2294  data: 0.0139  max mem: 3117
# Epoch: [9] Total time: 0:00:12 (0.2133 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:09  model_time: 0.1168 (0.1168)  evaluator_time: 0.0497 (0.0497)  time: 0.1815  data: 0.0151  max mem: 3117
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0836 (0.0930)  evaluator_time: 0.0327 (0.0381)  time: 0.1308  data: 0.0071  max mem: 3117
# Test: Total time: 0:00:06 (0.1393 s / it)
# Averaged stats: model_time: 0.0836 (0.0930)  evaluator_time: 0.0327 (0.0381)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.004
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.007
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.401
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.340
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.408
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000

# %%
# Demonstrate model comparison using the two models from the exercise
print("Comparing the two models with different learning rates...")

# Compare the original model (lr=0.005) with the new model (lr=0.001 - from exercise)
comparison_df, original_metrics, new_metrics = compare_models(
    model1=model,           # Original model trained with lr=0.005
    model2=new_model,       # New model from exercise (should be trained with lr=0.001)
    data_loader=data_loader_test,
    device=device,
    model1_name="Original Model (lr=0.005)",
    model2_name="Exercise Model (lr=0.001)"
)

# Display additional insights
print("\n📊 ADDITIONAL INSIGHTS:")
print("-" * 40)
print("• Lower learning rates (0.001) typically provide:")
print("  - More stable training")
print("  - Better final convergence") 
print("  - Reduced risk of overfitting")
print("  - Slower initial learning")
print("\n• Higher learning rates (0.005) typically provide:")
print("  - Faster initial learning")
print("  - Risk of overshooting optimal weights")
print("  - More training instability")
print("  - Potential for better exploration")
# Out:
# Comparing the two models with different learning rates...
# Evaluating Original Model (lr=0.005)...
# Evaluating Exercise Model (lr=0.001)...
#
# ================================================================================
# MODEL COMPARISON RESULTS
# ================================================================================
#            Metric Original Model (lr=0.005) Exercise Model (lr=0.001)              Better Model Difference
#      Mask_mAP@0.5                    0.9915                    0.0000 Original Model (lr=0.005)     0.9915
# Mask_mAP@0.5:0.95                    0.7463                    0.0000 Original Model (lr=0.005)     0.7463
#           mAP@0.5                    0.9915                    0.0911 Original Model (lr=0.005)     0.9004
#      mAP@0.5:0.95                    0.7963                    0.0220 Original Model (lr=0.005)     0.7743
#          mAP@0.75                    0.9017                    0.0041 Original Model (lr=0.005)     0.8976
#         mAP_large                    0.8124                    0.0523 Original Model (lr=0.005)     0.7601
#        mAP_medium                    0.6282                    0.0033 Original Model (lr=0.005)     0.6249
#         mAP_small                    0.5185                    0.0009 Original Model (lr=0.005)     0.5176
#
# ================================================================================
# 🏆 OVERALL WINNER: Original Model (lr=0.005)
#    Best mAP@0.5:0.95: 0.7963
# ================================================================================
#
# 📊 ADDITIONAL INSIGHTS:
# ----------------------------------------
# • Lower learning rates (0.001) typically provide:
#   - More stable training
#   - Better final convergence
#   - Reduced risk of overfitting
#   - Slower initial learning
#
# • Higher learning rates (0.005) typically provide:
#   - Faster initial learning
#   - Risk of overshooting optimal weights
#   - More training instability
#   - Potential for better exploration

# %% [markdown]
# ## Further Reading
#
# - [Vision Transformer Paper](https://arxiv.org/abs/2010.11929)
# - [DETR: End-to-End Object Detection with Transformers](https://arxiv.org/abs/2005.12872)
# - [Swin Transformer for Object Detection](https://arxiv.org/abs/2103.14030)
